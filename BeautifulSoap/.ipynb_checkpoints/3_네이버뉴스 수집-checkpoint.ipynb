# %%
# -*- coding: utf-8 -*-
from bs4 import BeautifulSoup
from datetime import datetime
import requests
import pandas as pd
import re
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''
< naver 뉴스 검색시 리스트 크롤링하는 프로그램 > _select사용
- 크롤링 해오는 것 : 링크,제목,신문사,날짜,내용요약본
- 날짜,내용요약본  -> 정제 작업 필요
- 리스트 -> 딕셔너리 -> df -> 엑셀로 저장 
'''''''''''''''''''''''''''''''''''''''''''''''''''''''''



now = datetime.now() #파일이름 현 시간으로 저장하기

#날짜 정제화 함수
def date_cleansing(test):
    try:
        #지난 뉴스
        #머니투데이  10면1단  2018.11.05.  네이버뉴스   보내기  
        pattern = '\d+.(\d+).(\d+).'  #정규표현식 
    
        r = re.compile(pattern)
        match = r.search(test).group(0)  # 2018.11.05.
        date_text.append(match)
        
    except AttributeError:
        #최근 뉴스
        #이데일리  1시간 전  네이버뉴스   보내기  
        pattern = '\w* (\d\w*)'     #정규표현식 
        
        r = re.compile(pattern)
        match = r.search(test).group(1)
        #print(match)
        date_text.append(match)


#내용 정제화 함수 
def contents_cleansing(contents):
    first_cleansing_contents = re.sub('<dl>.*?</a> </div> </dd> <dd>', '', 
                                      str(contents)).strip()  #앞에 필요없는 부분 제거
    second_cleansing_contents = re.sub('<ul class="relation_lst">.*?</dd>', '', 
                                       first_cleansing_contents).strip()#뒤에 필요없는 부분 제거 (새끼 기사)
    third_cleansing_contents = re.sub('<.+?>', '', second_cleansing_contents).strip()
    contents_text.append(third_cleansing_contents)
    #print(contents_text)

# %%
maxpage = 10
query = "금리"
sort = '1' #관련도순=0  최신순=1  오래된순=2
s_date = '2018.01.01'  #2019.01.04
e_date = '2019.12.31'  #2019.01.05

#각 크롤링 결과 저장하기 위한 리스트 선언 
title_text=[]
link_text=[]
source_text=[]
date_text=[]
contents_text=[]
result={}

# %%
s_from = s_date.replace(".","")
e_to = e_date.replace(".","")
page = 1  
maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지

while page <= maxpage_t:
    url = "https://search.naver.com/search.naver?where=news&query=" + query + "&sort="+sort+"&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)

    print(url)
    response = requests.get(url)
    html = response.text

    #뷰티풀소프의 인자값 지정
    soup = BeautifulSoup(html, 'html.parser')

    #<a>태그에서 제목과 링크주소 추출
    atags = soup.select('._sp_each_title')
    for atag in atags:
        title_text.append(atag.text)     #제목
        link_text.append(atag['href'])   #링크주소

    #신문사 추출
    source_lists = soup.select('._sp_each_source')
    for source_list in source_lists:
        source_text.append(source_list.text)    #신문사

    #날짜 추출 
    date_lists = soup.select('.txt_inline')
    for date_list in date_lists:
        test=date_list.text   
        date_cleansing(test)  #날짜 정제 함수사용 

    #본문요약본
    contents_lists = soup.select('ul.type01 dl')
    for contents_list in contents_lists:
        #print('==='*40)
        #print(contents_list)
        contents_cleansing(contents_list) #본문요약 정제화


    #모든 리스트 딕셔너리형태로 저장
    result= {"date" : date_text , "title":title_text ,  "source" : source_text ,"contents": contents_text ,"link":link_text }  
    #print(page)

    df = pd.DataFrame(result)  #df로 변환
    page += 10
# Out:
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=1
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=11
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=21
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=31
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=41
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=51
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=61
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=71
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=81
# https://search.naver.com/search.naver?where=news&query=금리&sort=1&ds=2018.01.01&de=2019.12.31&nso=so%3Ar%2Cp%3Afrom20180101to20191231%2Ca%3A&start=91

# %%
df
# Out:
#      date                                              title    source  \
# 0     16분                    [뉴욕채권] 미 국채가, 침체 우려 랠리…커브 역전 심화    연합인포맥스
# 1     32분     [글로벌 증시] 글로벌 경기침체 우려로 장단기 금리 역전...뉴욕증시 하락 다...      아주경제
# 2     36분                             농협 경남본부 "스마트공장 끝까지 지원"    경남도민일보
# 3     52분                        [뉴욕증시] 무역 전쟁-경기 침체 불안감에 '뚝'       뉴스핌
# 4     56분                    크래머 "처음으로 증시 안정 위해 국채 금리 상승 지지"    연합인포맥스
# 5     58분           KB국민은행, 영업채널 다각화...'6만 온라인 셀러' 고객 확보 속도전      이투데이
# 6     1시간  [뉴욕증시] 와르르 급락 다우지수 234p 나스닥 59p… 장단기 금리역전 + 트럼...   글로벌이코노믹
# 7     1시간                           [경제가 보인다]갈 길 먼 ‘미중 무역전쟁’    미주중앙일보
# 8     1시간                         [뉴욕유가] 경기 침체 우려 확산 0.6% 하락    연합인포맥스
# 9     1시간                         '가라앉는 금리' 지구촌 채권시장이 보내는 경고       뉴스핌
# 10    1시간     [분양 하이라이트] 천안 두정역 범양레우스 알파, 천안 첫 공공지원 민간 임대...      매일경제
# 11    2시간                   청량리역 아파트 '미계약' 걱정…은행 대출 알선하는 건설사      이데일리
# 12    2시간               펀드스트래트 "이번 커브 역전 1998년과 유사…침체 신호 아냐"    연합인포맥스
# 13  36면1단                            하나銀 ‘더하기 외화예금 신규가입’ 이벤트      서울신문
# 14  36면1단                                 똘똘한 자산전략으로 지갑 채워볼까      서울신문
# 15  22면1단                     몸값 오르는 달러… 금융 자산 10~15% 채워 두세요      서울신문
# 16  19면1단             총알 송금, 알짜 금리, 꽉찬 서비스… 베트남 사로잡은 ‘금융 한류’      서울신문
# 17   4면1단                 무역불안에 외국인 ‘셀 코리아’ 가속…주식·원화가치 동반 추락      서울신문
# 18   4면1단                무역불안에 외국인 ‘셀 코리아’ 가속… 주식·원화가치 동반 추락      서울신문
# 19    2시간                     BMO "캐나다 중앙은행, 오랜 기간 금리 동결할 것"    연합인포맥스
# 20    2시간                    멕시코 중앙은행, 올해 성장률 전망 0.3%p 하향 조정    연합인포맥스
# 21    2시간                         화웨이 달러채 소폭 하락…"美 맹공 견뎌낼 것"    연합인포맥스
# 22    2시간                     수출-고용 부진 한국, ‘잃어버린 20년’에 갇힐 수도      동아일보
# 23    2시간                   [뉴욕 금가격] 글로벌 경제 둔화 우려 고조 0.3% 상승    연합인포맥스
# 24    3시간           유럽 증시, 미중마찰 장기화·伊재정적자에 속락 마감...런던 1.15%↓       뉴시스
# 25    4시간       BNK부산은행, 신용보증기금과 사회적경제기업 활성화 위해 금융지원 업무협약...      위키트리
# 26    4시간                          [유럽증시] 경제·G2 무역 전쟁 우려에 하락       뉴스핌
# 27    4시간                              경북, 관광진흥기금 10년간 천억 조성    경상매일신문
# 28    4시간                   [주간 재테크 핫 이슈] 6월 증시 이벤트 점검과 투자전략      한라일보
# 29    5시간                       BNK부산은행-신용보증기금, 금융지원 업무협약 체결      경남일보
# ..    ...                                                ...       ...
# 70   10시간                        영세 관광사업자 특별지원 농협은행 대출상품 판매해      전북중앙
# 71   10시간                              광주·전남 소비자심리 4개월 연속 하락    광주매일신문
# 72   10시간                            영세 관광사업자 특별금융지원 대출상품 판매      전라일보
# 73   10시간              카카오뱅크 ‘거침없는 독주’...개인사업자 대상 사잇돌대출까지 출시     에너지경제
# 74   10시간                      [금융시장표] 금리금값(5월29일) 환율(5월29일)      부산일보
# 75   10시간                         국내 채권전문가 97% 이달 기준금리 동결 예상      아주경제
# 76   10시간                 부산은행과 신용보증기금, 부산 울산 경남 사회적기업에 금융지원   비즈니스포스트
# 77   10시간                       채권시장 전문가 97% “5월 기준금리 동결 전망”      인더뉴스
# 78   10시간                [아! 이 금융상품]흥국화재, ‘착한가격 더플러스통합보험’ 출시    이코노믹리뷰
# 79   11시간      원화환율, 내릴 때는 일주일 '꾸역꾸역' 오를 때는 '단숨에'... 엔화환율 하락     초이스경제
# 80   11시간                이데일리 ‘내일의 경제일정’-판 갈린 최저임금위원회, 심의 돌입      이데일리
# 81   11시간                       부산銀-신보, 사회적기업 활성화 위해 금융지원 협약    파이낸셜뉴스
# 82  27면1단                      [채권마감]글로벌 경기 우려…10년물도 기준금리 하회     머니투데이
# 83   11시간                             파멥신, 글로벌 임상 위해 전환사채 발행      헬로디디
# 84   11시간      카카오뱅크, 사잇돌대출 대상 개인사업자로 확대...소규모 자영업자, 프리랜서...  오가닉라이프신문
# 85   11시간                      빈대인 부산은행장, 신보와 사회적경제기업 활성화 나서    한국금융신문
# 86   11시간             [Today글로벌뉴스] 도요타, 中 디디추싱에 6500억원 출자 검토    이코노믹리뷰
# 87   11시간                KB증권 신용등급 'AA+'↑…KB금융그룹 편입 후 수익성 개선       뉴스핌
# 88   11시간                          [이슈플러스] 한국 인터넷은행, 방향타가 없다    서울경제TV
# 89   11시간                 ‘집 경매 안 넘기고 빚 상환’…주담대 채무조정 기회 늘어난다      아주경제
# 90   11시간                  채권전문가, 6월 BMSI 100.4…"기준금리 동결 예상"     프라임경제
# 91   11시간                 부산은행·신용보증기금, 사회적경제기업 활성화 금융지원 업무협약       뉴시스
# 92   11시간                          국내 채권전문가 97% "기준금리 동결 전망"       머니S
# 93   11시간            [김영미의 투어리즘 들여다보기] ‘2020 도쿄올림픽’ 반사이익 챙기자      광남일보
# 94   11시간                             경북도관광진흥기금 1000억 조성'순항'    경북도민일보
# 95   11시간   채권전문가 97% "5월 금통위 기준금리 동결"...경기둔화로 원화 약세 지속 우...  오가닉라이프신문
# 96   11시간                   NH농협은행 전북본부, 영세 관광사업자 특별금융 대출 지원    전북도민일보
# 97    11면                        연초이후 수익률 고공행진… J리츠펀드에 돈 몰린다    디지털타임스
# 98   11시간                     대출금리 내렸지만 보험사 대출↓…당국 DSR 규제 여파     스페셜경제
# 99   11시간              양산상의, '김병도 서울대학교 교수 초청' CEO 조찬 세미나 개최    울산매일신문
#
#                                              contents  \
# 0   10년 만기 국채수익률은 연방준비제도(Fed·연준)의 기준금리 하단을 하회했으며 3...
# 1   시장에 퍼진 글로벌 경기 위축 우려는 국채 금리 역전 현상으로 나타났다. 미국 국채...
# 2   경남본부는 재원 100억 원을 조성해 대출 보증료를 할인(0.4%p)해 주고 추가 ...
# 3   아울러 시카고상업거래소(CME)에 따르면 미 국채 선물은 내년 말까지 연방준비제도(...
# 4   국채 금리 상승을 지지하고 있다고 말했다. 29일 CNBC에 따르면 크래머는 "나는...
# 5   또 판매업자가 신용대출을 받으면 연 11~20%의 높은 금리로 이용해야 했지만 이 ...
# 6   미국 채권의 장단기 금리역전도 미국 뉴욕증시 다우지수 나스닥지수 S&amp;P 50...
# 7   김형진 이코노미스트와 하인혁 웨스턴캐롤라이나대 교수가 출연, 미중 무역전쟁 현황, ...
# 8   이에 안전자산으로 투자 수요가 몰리면서 미 국채 금리의 역전 현상도 심화했다. 이날...
# 9   시카고상업거래소(CME)에 따르면 미 국채 선물은 내년 말까지 연방준비제도(Fed)...
# 10  특히 자금력이 부족한 젊은 층이나 인근 빌라 거주 가구는 주택도시기금의 전세자금대출...
# 11  다만 분양가 9억원을 초과하는 가구도 시중 대출금리 보다 낮게 중도금 대출이 가능하...
# 12  이날 채권시장에서 미 국채 3개월물 금리는 10년물 금리보다 12베이시스포인트(bp...
# 13  KEB하나은행은 입출금이 자유로운 미 달러화 외화예금에 신규 가입하면 높은 금리와 ...
# 14  또한 채권형 ETF, 정기예금 등 상대적으로 금리가 높은 채권형 투자자산도 활용한다...
# 15  8%의 금리를 주는 이벤트를 진행 중이다. KB국민은행도 다음달 말까지 1만 달러 ...
# 16  빠른 거래 처리, 경쟁력 있는 금리, 그리고 서비스 정신 3가지로 요약된다. 신한 ...
# 17  채권시장에서는 3년물과 5년물에 이어 10년 만기 국고채 금리도 기준금리 아래로 떨...
# 18  코스피, 2020선 후퇴… 5개월새 최저치 국고채 10년물마저 기준금리 밑으로 뚝 ...
# 19  우성문 통신원 = BMO캐피털 마켓은 캐나다 중앙은행(BOC)이 오랜 기간 동안 금...
# 20  앞서 내년 2분기와 3분기 사이에 해당 물가 수준을 기록할 것으로 내다봤었다. 다우...
# 21  전체 발행 잔액은 약 45억 달러로, 만기는 2022년에서 2027년, 표면금리는 ...
# 22  로치 교수는 “추가 부양책이 필요하고, 중앙은행도 조금 더 공격적인 금리 인하에 나...
# 23  미국과 중국 간의 무역 갈등 긴장감이 유지되며 이날 미국의 국채 금리가 하락했다. ...
# 24  특히 은행주는 유럽 장기금리 저하를 배경으로 이윤축소를 우려하는 매물이 몰렸다. 소...
# 25  부산은행은 사회적경제기업들의 금융비용 부담 완화를 위해 대출금리를 최대 0.5%까지...
# 26  10년 만기 미 국채 금리는 거의 2년간 최저치로 떨어지며 경제에 대한 우려감을 반...
# 27  융자사업은 관광관련시설의 신축, 증축, 개보수 비용으로 담보능력에 따라 최대 5억원...
# 28  현재 투자자들은 연준의 금리인상 중단은 당연한 것으로 예상하고 있으며, 인하에 대한...
# 29  부산은행은 사회적경제기업들의 금융비용 부담 완화를 위해 대출금리를 최대 0.5%까지...
# ..                                                ...
# 70  대출가능금액은 최대 5천만원으로 2년 거치 3년 원금균등분할(3개월 주기)로 상환하...
# 71  취업기회, 금리수준 전망 등은 하락했다. 한국은행 광주·전남본부가 29일 발표한 ‘...
# 72  대출가능금액은 최대 5천만 원으로 2년 거치 3년 원금균등분할(3개월 주기)로 상환...
# 73  중금리 대출 상품 라인업 확대에 나섰다. 개인사업자 사잇돌대출 상품은 소규모 자영업...
# 74
# 75  기준금리가 동결될 것이라고 예상했다. 금융투자협회는 지난 16~21일 104개 기관...
# 76  부산은행은 사회적경제기업들의 금융비용 부담을 낮춰주기 위해 대출금리를 최대 0.5%...
# 77  기준금리 결정에 동결로 예상했다고 29일 발표했다. 지난 16일부터 21일까지 채권...
# 78  ■ 카카오뱅크, 모바일 전용 ‘개인사업자 사잇돌대출’ 출시 카카오뱅크는 중금리 대출...
# 79  한국은행의 31일 금융통화위원회 회의는 기준금리 결정뿐만 아니라 향후 통화정책 기조...
# 80  가중평균금리 12:00 한국은행, 2019년 1분기중 주요 기관투자가의 외화증권투자...
# 81  부산은행은 사회적경제기업들의 금융비용 부담 완화를 위해 대출금리를 최대 0.5%포인...
# 82  미·중 무역분쟁으로 글로벌 경기 우려가 커지면서 국채금리가 하락 마감했다. 국고채 ...
# 83  이번에 발행하는 전환사채는 5년 만기에 표면금리와 만기수익률 모두 0%이며, 옵션으...
# 84  대출 최대 한도는 2000만원이며 이날 기준 대출 최저금리는 3.48%이다. 또 카...
# 85  부산은행은 사회적경제기업들의 금융비용 부담 완화를 위해 대출금리를 최대 0.5%까지...
# 86  [미국] ■ 美 국채에 몰리는 돈, 금리 1년 8개월만에 최저 - 글로벌 경제 성장...
# 87  한신평은 보고서에서 "채권금리 안정화로 인한 재기매매 및 운용부문실적 개선 등으로 ...
# 88  정부가 인터넷은행에 중금리 대출을 특화해서 해주라고 하는 것도 잘 생각해보면 앞뒤가...
# 89  이외에도 채무조정 시 분할상환은 기본 적용하되 상환유예와 금리감면 등은 채무자의 형...
# 90  국내 채권시장 전문가들이 오는 31일 한국은행 금융통화위원회에서 기준금리를 동결할 ...
# 91  부산은행은 사회적경제기업들의 금융비용 부담 완화를 위해 대출금리를 최대 0.5%까지...
# 92  채권시장 전문가들은 오는 31일 한국은행 금융통화위원회가 기준금리를 연 1.75%로...
# 93  집권 이후 마이너스 금리, 엔화 약세, 주가 상승 등 인위적인 경기부양책을 펼친 결...
# 94  융자사업은 관광관련시설의 신축, 증축, 개보수 비용으로 담보능력에 따라 최대 5억원...
# 95  금리를 현행 연 1.75%로 동결할 것으로 전망했다. 금융투자협회는 29일 '201...
# 96  대출가능금액은 최대 5천만원으로 2년 거치 3년 원금균등분할(3개월 주기)로 상환하...
# 97  저금리 기조를 유지하려는 일본 정부와 일본 은행의 의지로 저금리 상황은 적어도 내년...
# 98  ▲ [자료출처=생명보험협회 홈페이지] 이에 보험사들은 대출금리를 낮추며 대출을 모집...
# 99  하지만 요즘 기업을 보면 정부의 각종 규제를 비롯해 금리·환율 등 기업 경영환경의 ...
#
#                                                  link
# 0   http://news.einfomax.co.kr/news/articleView.ht...
# 1       http://www.ajunews.com/view/20190530052538562
# 2   http://www.idomin.com/?mod=news&act=articleVie...
# 3     http://www.newspim.com/news/view/20190530000021
# 4   http://news.einfomax.co.kr/news/articleView.ht...
# 5   http://www.etoday.co.kr/news/section/newsview....
# 6   http://www.g-enews.com/ko-kr/news/article/news...
# 7   http://www.koreadaily.com/news/read.asp?art_id...
# 8   http://news.einfomax.co.kr/news/articleView.ht...
# 9     http://www.newspim.com/news/view/20190530000017
# 10  http://news.mk.co.kr/newsRead.php?year=2019&no...
# 11  http://www.edaily.co.kr/news/newspath.asp?news...
# 12  http://news.einfomax.co.kr/news/articleView.ht...
# 13  https://www.seoul.co.kr/news/newsView.php?id=2...
# 14  https://www.seoul.co.kr/news/newsView.php?id=2...
# 15  https://www.seoul.co.kr/news/newsView.php?id=2...
# 16  https://www.seoul.co.kr/news/newsView.php?id=2...
# 17  https://www.seoul.co.kr/news/newsView.php?id=2...
# 18  https://www.seoul.co.kr/news/newsView.php?id=2...
# 19  http://news.einfomax.co.kr/news/articleView.ht...
# 20  http://news.einfomax.co.kr/news/articleView.ht...
# 21  http://news.einfomax.co.kr/news/articleView.ht...
# 22    http://news.donga.com/3/all/20190529/95760974/1
# 23  http://news.einfomax.co.kr/news/articleView.ht...
# 24  http://www.newsis.com/view/?id=NISX20190530_00...
# 25  http://www.wikitree.co.kr/main/news_view.php?i...
# 26    http://www.newspim.com/news/view/20190530000005
# 27  http://www.ksmnews.co.kr/default/index_view_pa...
# 28  http://www.ihalla.com/read.php3?aid=1559142000...
# 29  http://www.gnnews.co.kr/news/articleView.html?...
# ..                                                ...
# 70  http://www.jjn.co.kr/news/articleView.html?idx...
# 71  http://www.kjdaily.com/read.php3?aid=155912507...
# 72  http://www.jeollailbo.com/news/articleView.htm...
# 73      http://www.ekn.kr/news/article.html?no=434731
# 74  http://www.busan.com/view/busan/view.php?code=...
# 75      http://www.ajunews.com/view/20190529190025465
# 76  http://www.businesspost.co.kr/BP?command=artic...
# 77  http://www.inthenews.co.kr/news/article.html?n...
# 78  http://www.econovill.com/news/articleView.html...
# 79  http://www.choicenews.co.kr/news/articleView.h...
# 80  http://www.edaily.co.kr/news/newspath.asp?news...
# 81      http://www.fnnews.com/news/201905291840397117
# 82  http://news.mt.co.kr/mtview.php?no=20190529182...
# 83      http://hellodd.com/?md=news&mt=view&pid=68570
# 84  http://www.iloveorganic.co.kr/news/articleView...
# 85  http://www.fntimes.com/html/view.php?ud=201905...
# 86  http://www.econovill.com/news/articleView.html...
# 87    http://www.newspim.com/news/view/20190529001061
# 88            http://www.sentv.co.kr/news/view/554487
# 89      http://www.ajunews.com/view/20190529154431218
# 90  http://www.newsprime.co.kr/news/article.html?n...
# 91  http://www.newsis.com/view/?id=NISX20190529_00...
# 92  http://moneys.mt.co.kr/news/mwView.php?no=2019...
# 93  http://www.gwangnam.co.kr/read.php3?aid=155912...
# 94  http://www.hidomin.com/news/articleView.html?i...
# 95  http://www.iloveorganic.co.kr/news/articleView...
# 96  http://www.domin.co.kr/news/articleView.html?i...
# 97  http://www.dt.co.kr/contents.html?article_no=2...
# 98  http://speconomy.com/news/newsview.php?ncode=1...
# 99  http://www.iusm.co.kr/news/articleView.html?id...
#
# [100 rows x 5 columns]
